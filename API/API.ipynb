# %%
import requests
import json
import pandas as pd


api_key ="YOUR API"
city="Sangli"

# url=f"https://api.openweathermap.org/data/2.5/forecast?q={city}&appid={api_key}"
url=f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}"


response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    print(json.dumps(data,indent=4))
    with open ("data2.json","w") as file:
        json.dump(data,file)
else:
    print(f"Error:{response.status_code}")


print("........")

df = pd.read_csv("data2.json")
d =pd.DataFrame(df)


print(d)
# Out:
# {
#     "coord": {
#         "lon": 74.5642,
#         "lat": 16.8544
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 295.66,
#         "feels_like": 296.29,
#         "temp_min": 295.66,
#         "temp_max": 295.66,
#         "pressure": 1008,
#         "humidity": 89,
#         "sea_level": 1008,
#         "grnd_level": 944
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 5.88,
#         "deg": 245,
#         "gust": 11.84
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1724689397,
#     "sys": {
#         "country": "IN",
#         "sunrise": 1724633253,
#         "sunset": 1724678397
#     },
#     "timezone": 19800,
#     "id": 1257416,
#     "name": "Sangli",
#     "cod": 200
# }
# ........
# Empty DataFrame
# Columns: [{"coord": {"lon": 74.5642,  "lat": 16.8544},  "weather": [{"id": 804,  "main": "Clouds",  "description": "overcast clouds",  "icon": "04n"}],  "base": "stations",  "main": {"temp": 295.66,  "feels_like": 296.29,  "temp_min": 295.66,  "temp_max": 295.66,  "pressure": 1008,  "humidity": 89,  "sea_level": 1008,  "grnd_level": 944},  "visibility": 10000,  "wind": {"speed": 5.88,  "deg": 245,  "gust": 11.84},  "clouds": {"all": 100},  "dt": 1724689397,  "sys": {"country": "IN",  "sunrise": 1724633253,  "sunset": 1724678397},  "timezone": 19800,  "id": 1257416,  "name": "Sangli",  "cod": 200}]
# Index: []
#
# [0 rows x 28 columns]
